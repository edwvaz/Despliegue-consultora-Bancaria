# %%
import pandas as pd
import os
import utils
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Todos los archivos de la carpeta metadata-sitios tienen la misma estructura de columnas.

# %%
utils.dataStructure('../data/Google_Maps/metadata-sitios')
# Out:
# ['name',
#  'address',
#  'gmap_id',
#  'description',
#  'latitude',
#  'longitude',
#  'category',
#  'avg_rating',
#  'num_of_reviews',
#  'price',
#  'hours',
#  'MISC',
#  'state',
#  'relative_results',
#  'url']

# %% [markdown]
# Todos los archivos de la carpeta reviews-estados tienen la misma estructura de columnas.

# %%
utils.dataStructure('../data/Google_Maps/reviews-estados')
# Out:
# ['user_id', 'name', 'time', 'rating', 'text', 'pics', 'resp', 'gmap_id']

# %% [markdown]
# Los archivos business.pkl, tip.json y user.parquet de Yelp requiere transformación de datos.

# %%
utils.processFiles('../data/Yelp')
# Out:
# Se encontraron columnas duplicadas con datos en data/Yelp\business.pkl.
# data/Yelp\business.pkl contiene múltiples tipos de dato.
# data/Yelp\business.pkl contiene datos nulos.
# data/Yelp\checkin.json está OK.
# data/Yelp\review.json está OK.
# Se encontraron filas duplicadas data/Yelp\tip.json
# Se encontraron filas duplicadas data/Yelp\user.parquet

# %% [markdown]
# Todos los datasets de la carpeta Google_Maps (approx. 600 archivos json) requieren transformación de datos.

# %%
utils.processFiles('../data/Google_Maps')
# Out:
# ../data/Google_Maps\metadata-sitios\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\metadata-sitios\1.json
# ../data/Google_Maps\metadata-sitios\10.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\10.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\11.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\11.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\2.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\2.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\3.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\3.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\4.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\4.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\5.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\5.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\6.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\6.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\7.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\7.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\8.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\8.json contiene datos nulos.
# ../data/Google_Maps\metadata-sitios\9.json contiene múltiples tipos de dato.
# ../data/Google_Maps\metadata-sitios\9.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alabama\1.json
# ../data/Google_Maps\reviews-estados\review-Alabama\10.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\10.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\11.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\11.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\12.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\12.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\2.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\2.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alabama\2.json
# ../data/Google_Maps\reviews-estados\review-Alabama\3.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\3.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alabama\3.json
# ../data/Google_Maps\reviews-estados\review-Alabama\4.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\4.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alabama\4.json
# ../data/Google_Maps\reviews-estados\review-Alabama\5.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\5.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alabama\5.json
# ../data/Google_Maps\reviews-estados\review-Alabama\6.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\6.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\7.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\7.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\8.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\8.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alabama\9.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alabama\9.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Alaska\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alaska\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alaska\1.json
# ../data/Google_Maps\reviews-estados\review-Alaska\2.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alaska\2.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alaska\2.json
# ../data/Google_Maps\reviews-estados\review-Alaska\3.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alaska\3.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alaska\3.json
# ../data/Google_Maps\reviews-estados\review-Alaska\4.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Alaska\4.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Alaska\4.json
# ../data/Google_Maps\reviews-estados\review-Arizona\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\1.json
# ../data/Google_Maps\reviews-estados\review-Arizona\10.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\10.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arizona\11.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\11.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arizona\12.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\12.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arizona\13.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\13.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arizona\14.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\14.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arizona\2.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\2.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\2.json
# ../data/Google_Maps\reviews-estados\review-Arizona\3.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\3.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\3.json
# ../data/Google_Maps\reviews-estados\review-Arizona\4.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\4.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\4.json
# ../data/Google_Maps\reviews-estados\review-Arizona\5.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\5.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\5.json
# ../data/Google_Maps\reviews-estados\review-Arizona\6.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\6.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\6.json
# ../data/Google_Maps\reviews-estados\review-Arizona\7.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\7.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\7.json
# ../data/Google_Maps\reviews-estados\review-Arizona\8.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\8.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\8.json
# ../data/Google_Maps\reviews-estados\review-Arizona\9.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arizona\9.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arizona\9.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\1.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\10.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\10.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\10.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\11.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\11.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\11.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\12.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\12.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\12.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\13.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\13.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\14.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\14.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\14.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\15.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\15.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\15.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\16.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\16.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\16.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\2.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\2.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\2.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\3.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\3.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\3.json
# ../data/Google_Maps\reviews-estados\review-Arkansas\4.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\4.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\5.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\5.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\6.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\6.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\7.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\7.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\8.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\8.json contiene datos nulos.
# ../data/Google_Maps\reviews-estados\review-Arkansas\9.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-Arkansas\9.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-Arkansas\9.json
# ../data/Google_Maps\reviews-estados\review-California\1.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-California\1.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-California\1.json
# ../data/Google_Maps\reviews-estados\review-California\10.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-California\10.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-California\10.json
# ../data/Google_Maps\reviews-estados\review-California\11.json contiene múltiples tipos de dato.
# ../data/Google_Maps\reviews-estados\review-California\11.json contiene datos nulos.
# Se encontraron filas duplicadas ../data/Google_Maps\reviews-estados\review-California